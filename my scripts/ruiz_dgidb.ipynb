# %%
import pandas as pd
import numpy as np

# Load DGIdb files with only necessary columns
interactions_columns = ['gene_name', 'drug_concept_id', 'interaction_group_score']
genes_columns = ['gene_name', 'gene_claim_name']
drugs_columns = ['drug_claim_name', 'concept_id']

# DGIdb files
drugs_df = pd.read_csv('../data/indication_gene_link/dgidb/drugs.tsv', sep='\t', usecols=drugs_columns)
genes_df = pd.read_csv('../data/indication_gene_link/dgidb/genes.tsv', sep='\t', usecols=genes_columns)
interactions_df = pd.read_csv('../data/indication_gene_link/dgidb/interactions.tsv', sep='\t', usecols=interactions_columns)

# %%
# Handle missing values before merging
drugs_df.dropna(subset=['concept_id'], inplace=True)
genes_df.dropna(subset=['gene_name'], inplace=True)
interactions_df.dropna(subset=['drug_concept_id'], inplace=True)

# %%
# Merge DGIdb data
dgIdb_merged = pd.merge(interactions_df, genes_df, on='gene_name', how='inner')
dgIdb_merged = pd.merge(dgIdb_merged, drugs_df, left_on='drug_concept_id', right_on='concept_id', how='inner')
dgIdb_merged['drug_concept_id'] = dgIdb_merged['drug_concept_id'].str.replace('chembl:', '', regex=False)

dgIdb_merged.tail(30)
# Out:
#         gene_name drug_concept_id  interaction_group_score  \
# 4230272      GCH1    CHEMBL219568                   127.30
# 4230273      GCH1    CHEMBL219568                   127.30
# 4230274   TNFSF12   CHEMBL2109600                   127.30
# 4230275   TNFSF12   CHEMBL2109600                   127.30
# 4230276   TNFSF12   CHEMBL2109600                   127.30
# 4230277   TNFSF12   CHEMBL2109600                   127.30
# 4230278   TNFSF12   CHEMBL2109600                   127.30
# 4230279   TNFSF12   CHEMBL2109600                   127.30
# 4230280      LIFR   CHEMBL2108400                   127.30
# 4230281      LIFR   CHEMBL2108400                   127.30
# 4230282      LIFR   CHEMBL2108400                   127.30
# 4230283      LIFR   CHEMBL2108400                   127.30
# 4230284      LIFR   CHEMBL2108400                   127.30
# 4230285      LIFR   CHEMBL2108400                   127.30
# 4230286      LIFR   CHEMBL2108400                   127.30
# 4230287      LIFR   CHEMBL2108400                   127.30
# 4230288      LIFR   CHEMBL2108400                   127.30
# 4230289      LIFR   CHEMBL2108400                   127.30
# 4230290      LIFR   CHEMBL2108400                   127.30
# 4230291      LIFR   CHEMBL2108400                   127.30
# 4230292     UQCRB   CHEMBL1669042                   127.30
# 4230293     UQCRB   CHEMBL1669042                   127.30
# 4230294     UQCRB   CHEMBL1669042                   127.30
# 4230295     UQCRB   CHEMBL1669042                   127.30
# 4230296     CCL20   CHEMBL4297967                    63.65
# 4230297     CCL20   CHEMBL4297967                    63.65
# 4230298     CCL20   CHEMBL4297967                    63.65
# 4230299     CCL20   CHEMBL4297967                    63.65
# 4230300     CCL20   CHEMBL4297967                    63.65
# 4230301     CCL20   CHEMBL4297967                    63.65
#
#                                   gene_claim_name       drug_claim_name  \
# 4230272                      GTP cyclohydrolase-I   chembl:CHEMBL219568
# 4230273                      GTP cyclohydrolase-I               Guanine
# 4230274                           ENSG00000239697  chembl:CHEMBL2109600
# 4230275                           ENSG00000239697            RO-5458640
# 4230276                           ENSG00000239697  chembl:CHEMBL2109600
# 4230277                           ENSG00000239697            RO-5458640
# 4230278     TNF-related weak inducer of apoptosis  chembl:CHEMBL2109600
# 4230279     TNF-related weak inducer of apoptosis            RO-5458640
# 4230280                                      3977            Emfilermin
# 4230281                                      3977  chembl:CHEMBL2108400
# 4230282                           ENSG00000113594            Emfilermin
# 4230283                           ENSG00000113594  chembl:CHEMBL2108400
# 4230284                                      LIFR            Emfilermin
# 4230285                                      LIFR  chembl:CHEMBL2108400
# 4230286       Leukemia inhibitory factor receptor            Emfilermin
# 4230287       Leukemia inhibitory factor receptor  chembl:CHEMBL2108400
# 4230288                           ENSG00000113594            Emfilermin
# 4230289                           ENSG00000113594  chembl:CHEMBL2108400
# 4230290                                      LIFR            Emfilermin
# 4230291                                      LIFR  chembl:CHEMBL2108400
# 4230292                                     UQCRB  chembl:CHEMBL1669042
# 4230293                                     UQCRB           TERPESTACIN
# 4230294                           ENSG00000156467  chembl:CHEMBL1669042
# 4230295                           ENSG00000156467           TERPESTACIN
# 4230296                           ENSG00000115009            GSK3050002
# 4230297                           ENSG00000115009  chembl:CHEMBL4297967
# 4230298                           ENSG00000115009            GSK3050002
# 4230299                           ENSG00000115009  chembl:CHEMBL4297967
# 4230300  Liver and activation-regulated chemokine            GSK3050002
# 4230301  Liver and activation-regulated chemokine  chembl:CHEMBL4297967
#
#                    concept_id
# 4230272   chembl:CHEMBL219568
# 4230273   chembl:CHEMBL219568
# 4230274  chembl:CHEMBL2109600
# 4230275  chembl:CHEMBL2109600
# 4230276  chembl:CHEMBL2109600
# 4230277  chembl:CHEMBL2109600
# 4230278  chembl:CHEMBL2109600
# 4230279  chembl:CHEMBL2109600
# 4230280  chembl:CHEMBL2108400
# 4230281  chembl:CHEMBL2108400
# 4230282  chembl:CHEMBL2108400
# 4230283  chembl:CHEMBL2108400
# 4230284  chembl:CHEMBL2108400
# 4230285  chembl:CHEMBL2108400
# 4230286  chembl:CHEMBL2108400
# 4230287  chembl:CHEMBL2108400
# 4230288  chembl:CHEMBL2108400
# 4230289  chembl:CHEMBL2108400
# 4230290  chembl:CHEMBL2108400
# 4230291  chembl:CHEMBL2108400
# 4230292  chembl:CHEMBL1669042
# 4230293  chembl:CHEMBL1669042
# 4230294  chembl:CHEMBL1669042
# 4230295  chembl:CHEMBL1669042
# 4230296  chembl:CHEMBL4297967
# 4230297  chembl:CHEMBL4297967
# 4230298  chembl:CHEMBL4297967
# 4230299  chembl:CHEMBL4297967
# 4230300  chembl:CHEMBL4297967
# 4230301  chembl:CHEMBL4297967

# %%
# Ruiz data
ruiz_df = pd.read_csv('../data/indication_gene_link/ruiz_filtered_data.csv')

from chembl_webresource_client.new_client import new_client

# Create a function to fetch ChEMBL ID using DrugBank ID
def get_chembl_id_from_drugbank(drugbank_id):
    try:
        # Use the new_client to search for the drug
        res = new_client.molecule.search(drugbank_id)
        # If there are results and ChEMBL ID is present, return it
        if res:
            chembl_id = res[0]['molecule_chembl_id']
            return chembl_id if chembl_id else None
        return None
    except Exception as e:
        print(f"Error fetching ChEMBL ID for DrugBank ID {drugbank_id}: {e}")
        return None


ruiz_df['chembl_id'] = ruiz_df['drug'].apply(get_chembl_id_from_drugbank)
ruiz_df.head(100)
# Out:
#        drug      drug_name indication  \
# 0   DB00130  glutamine-(l)   C0003467
# 1   DB00163      Vitamin E   C0002395
# 2   DB00176    fluvoxamine   C0028768
# 3   DB00182    Amphetamine   C1263846
# 4   DB00186      lorazepam   C0003467
# ..      ...            ...        ...
# 95  DB01151    desipramine   C0011581
# 96  DB01156      bupropion   C0011581
# 97  DB01156      bupropion   C1269683
# 98  DB01171    moclobemide   C0011581
# 99  DB01171    moclobemide   C0003467
#
#                                     indication_name  \
# 0                                           anxiety
# 1                               Alzheimer's disease
# 2               obsessive compulsive disorder (OCD)
# 3   attention-deficit/hyperactivity disorder (ADHD)
# 4                                           anxiety
# ..                                              ...
# 95                              Depressive disorder
# 96                              Depressive disorder
# 97                        Major Depressive Disorder
# 98                              Depressive disorder
# 99                                          anxiety
#
#                                      Disease    chembl_id
# 0                           Anxiety Disorder    CHEMBL930
# 1                        Alzheimer’s Disease     CHEMBL47
# 2                    OCD & Tourette Syndrome    CHEMBL814
# 3   Attention Deficit Hyperactivity Disorder    CHEMBL405
# 4                           Anxiety Disorder    CHEMBL580
# ..                                       ...          ...
# 95                 Major Depressive Disorder     CHEMBL72
# 96                 Major Depressive Disorder    CHEMBL894
# 97                 Major Depressive Disorder    CHEMBL894
# 98                 Major Depressive Disorder  CHEMBL86304
# 99                          Anxiety Disorder  CHEMBL86304
#
# [100 rows x 6 columns]

# %%
# merge with the DGIdb data using the 'chembl_id' column
merged_df = pd.merge(ruiz_df, dgIdb_merged, left_on='chembl_id', right_on='drug_concept_id', how='inner')

# Select and rename required columns
final_df = merged_df[['indication', 'indication_name', 'Disease', 'chembl_id', 'drug_name', 'gene_name', 'gene_claim_name']]
final_df.rename(columns={'chembl_id': 'drugbank_id', 'drug_name': 'db_name'}, inplace=True)

# Rename the 'drug' column to 'drugbank_id'
final_df.rename(columns={'drug': 'drugbank_id'}, inplace=True)

# Remove duplicate rows
final_df.drop_duplicates(inplace=True)

# Display the head of the final DataFrame to check the changes
final_df.head(100)
# Out:
# /var/folders/2n/0rd0mk2x3_d8gj2c6f3wlmy80000gn/T/ipykernel_45458/1196931004.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.rename(columns={'chembl_id': 'drugbank_id', 'drug_name': 'db_name'}, inplace=True)
# /var/folders/2n/0rd0mk2x3_d8gj2c6f3wlmy80000gn/T/ipykernel_45458/1196931004.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.rename(columns={'drug': 'drugbank_id'}, inplace=True)
# /var/folders/2n/0rd0mk2x3_d8gj2c6f3wlmy80000gn/T/ipykernel_45458/1196931004.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop_duplicates(inplace=True)
#     indication                      indication_name                  Disease  \
# 0     C0003467                              anxiety         Anxiety Disorder
# 5     C0003467                              anxiety         Anxiety Disorder
# 15    C0003467                              anxiety         Anxiety Disorder
# 20    C0003467                              anxiety         Anxiety Disorder
# 25    C0003467                              anxiety         Anxiety Disorder
# ..         ...                                  ...                      ...
# 883   C0028768  obsessive compulsive disorder (OCD)  OCD & Tourette Syndrome
# 891   C0028768  obsessive compulsive disorder (OCD)  OCD & Tourette Syndrome
# 899   C0028768  obsessive compulsive disorder (OCD)  OCD & Tourette Syndrome
# 915   C0028768  obsessive compulsive disorder (OCD)  OCD & Tourette Syndrome
# 955   C0028768  obsessive compulsive disorder (OCD)  OCD & Tourette Syndrome
#
#     drugbank_id        db_name gene_name   gene_claim_name
# 0     CHEMBL930  glutamine-(l)       GLS               GLS
# 5     CHEMBL930  glutamine-(l)       GLS   ENSG00000115419
# 15    CHEMBL930  glutamine-(l)       GLS       Glutaminase
# 20    CHEMBL930  glutamine-(l)       GLS              2744
# 25    CHEMBL930  glutamine-(l)     DDIT3             DDIT3
# ..          ...            ...       ...               ...
# 883   CHEMBL814    fluvoxamine     HTR2A            P28223
# 891   CHEMBL814    fluvoxamine     HTR2A             HTR2A
# 899   CHEMBL814    fluvoxamine     HTR2A  5-HT 2A receptor
# 915   CHEMBL814    fluvoxamine     HTR2A              3356
# 955   CHEMBL814    fluvoxamine     HTR2A              HTR2
#
# [100 rows x 7 columns]

# %%
# Save to a single file
final_df.to_csv('../data/indication_gene_link/ruiz_dgidb.csv', index=False)
