# %%
import pandas as pd
import numpy as np

columns = ['Parent Molecule ChEMBL ID', 'MESH ID', 'MESH Heading','EFO IDs', 'EFO Terms', 'Parent Molecule Name']
indication_df = pd.read_csv('../data/indication_gene_link/chembl_indication.csv', sep=';', usecols=columns)

indication_df.head()
# Out:
#   Parent Molecule ChEMBL ID Parent Molecule Name  MESH ID  \
# 0             CHEMBL1201784   HEXAMINOLEVULINATE  D001749
# 1             CHEMBL2221250          CAPREOMYCIN  D010019
# 2                 CHEMBL651            METHADONE  D009293
# 3             CHEMBL1822792              MK-2461  D009369
# 4             CHEMBL2146883          COBIMETINIB  D013274
#
#                 MESH Heading                  EFO IDs  \
# 0  Urinary Bladder Neoplasms            MONDO:0001187
# 1              Osteomyelitis              EFO:0003102
# 2   Opioid-Related Disorders  EFO:0005611|EFO:0010702
# 3                  Neoplasms  EFO:0000616|EFO:0000311
# 4          Stomach Neoplasms              EFO:0000503
#
#                                EFO Terms
# 0                 urinary bladder cancer
# 1                          osteomyelitis
# 2  opioid dependence|opioid use disorder
# 3                        neoplasm|cancer
# 4                 gastric adenocarcinoma

# %%
disease_synonyms = {
    "Attention Deficit Hyperactivity Disorder": ["ADHD", "Attention", "Hyperkinetic Syndrome", "Brain Dysfunction"],
    "Alzheimer’s Disease": ["Alzheimer"],
    "Anxiety Disorder": ["Anxiety", "Hypervigilance", "Nervousness", "Anxiousness", "Anxieties"],
    "Autism Spectrum Disorder": ["ASD", "Autism", "Autistic"],
    "Bipolar Disorder": ["Manic Depression", "Bipolar", "BPAD", "Bipolar disorder"],
    "Eating Disorders": ["Eating", "Feeding"],
    "Major Depressive Disorder": ["Depressive", "MDD", "Involutional Paraphrenia", "depression"],
    "OCD & Tourette Syndrome": ["Obsessive", "OCD", "Tourette", "Compulsive"],
    "Post Traumatic Stress Disorder": ["Post Traumatic Stress Disorder", "PTSD", "Post-Traumatic Stress"],
    "Schizophrenia": ["Schizoaffective Disorder", "Schizophrenia"],
    "Substance Use Disorders": ["Substance Use Disorders", "SUD", "Drug Use", "Drug Abuse", "Substance Dependence", "Opioid dependence", "Opioid use","Cannabis use disorder", "Alcohol use", "Alcohol dependence"]
}

def find_main_disease(indication_name):
    indication_name_lower = indication_name.lower() if isinstance(indication_name, str) else ''
    for main_disease, synonyms in disease_synonyms.items():
        if main_disease.lower() in indication_name_lower:
            return main_disease
        for synonym in synonyms:
            if synonym.lower() in indication_name_lower:
                return main_disease
    return None  # Return None to indicate no match was found

# Apply the function to each row in 'MESH Heading' and 'EFO Terms' columns and create a new 'Disease' column
filtered_indications = indication_df.copy()
filtered_indications['Disease'] = filtered_indications['MESH Heading'].apply(find_main_disease)
filtered_indications['Disease'] = filtered_indications.apply(
    lambda row: row['Disease'] if row['Disease'] is not None else find_main_disease(row['EFO Terms']), axis=1
)

# Filter out rows where 'Disease' is None (Unknown)
filtered_indications = filtered_indications.dropna(subset=['Disease'])

# Now 'filtered_indications' DataFrame will have the relevant rows with the 'Disease' column populated
print(filtered_indications)
# Out:
#       Parent Molecule ChEMBL ID Parent Molecule Name  MESH ID  \
# 2                     CHEMBL651            METHADONE  D009293
# 37                CHEMBL2028019          CARIPRAZINE  D001714
# 89                  CHEMBL43048       MIDOMAFETAMINE  D001007
# 109               CHEMBL2111047           PROLINTANE  D001289
# 111               CHEMBL1237021           LURASIDONE  D003866
# ...                         ...                  ...      ...
# 45466             CHEMBL2108308          TERTOMOTIDE  D000544
# 45480                 CHEMBL490           PAROXETINE  D001714
# 45521             CHEMBL1232801         FOLINIC ACID  D012559
# 45543                 CHEMBL809           SERTRALINE  D012559
# 45552               CHEMBL36715            PIRACETAM  D001007
#
#                                         MESH Heading                  EFO IDs  \
# 2                           Opioid-Related Disorders  EFO:0005611|EFO:0010702
# 37                                  Bipolar Disorder  EFO:0000289|EFO:0009963
# 89                                           Anxiety              EFO:0005230
# 109    Attention Deficit Disorder with Hyperactivity              EFO:0003888
# 111                              Depressive Disorder            MONDO:0002050
# ...                                              ...                      ...
# 45466                              Alzheimer Disease            MONDO:0004975
# 45480                               Bipolar Disorder              EFO:0000289
# 45521                                  Schizophrenia            MONDO:0005090
# 45543                                  Schizophrenia            MONDO:0005090
# 45552                                        Anxiety              EFO:0005230
#
#                                       EFO Terms  \
# 2         opioid dependence|opioid use disorder
# 37          bipolar disorder|bipolar I disorder
# 89                                      anxiety
# 109    attention deficit hyperactivity disorder
# 111                         depressive disorder
# ...                                         ...
# 45466                         Alzheimer disease
# 45480                          bipolar disorder
# 45521                             schizophrenia
# 45543                             schizophrenia
# 45552                                   anxiety
#
#                                         Disease
# 2                       Substance Use Disorders
# 37                             Bipolar Disorder
# 89                             Anxiety Disorder
# 109    Attention Deficit Hyperactivity Disorder
# 111                   Major Depressive Disorder
# ...                                         ...
# 45466                       Alzheimer’s Disease
# 45480                          Bipolar Disorder
# 45521                             Schizophrenia
# 45543                             Schizophrenia
# 45552                          Anxiety Disorder
#
# [1983 rows x 7 columns]

# %%
gene_df = pd.read_csv('../data/indication_gene_link/Chembl_drug_targets_ChEMBLID_UniProtIDs_EnsemblIDs.csv')

target_df = pd.read_csv('../data/indication_gene_link/chembl_mechnism.csv', sep=';')

target_df = target_df[["Parent Molecule ChEMBL ID", "Mechanism of Action", "Target ChEMBL ID"]]

target_df = target_df.merge(filtered_indications[['Parent Molecule ChEMBL ID', 'Parent Molecule Name','MESH Heading','EFO Terms', 'EFO IDs', 'Disease']], on='Parent Molecule ChEMBL ID')

merged_df = target_df.merge(gene_df, left_on="Target ChEMBL ID", right_on="ChEMBLID")

merged_df = merged_df[['Parent Molecule ChEMBL ID','Parent Molecule Name', 'EnsemblID', 'MESH Heading','EFO Terms','EFO IDs','Disease']]

merged_df.head(30)
# Out:
#    Parent Molecule ChEMBL ID Parent Molecule Name        EnsemblID  \
# 0                  CHEMBL134            CLONIDINE  ENSG00000150594
# 1                  CHEMBL134            CLONIDINE  ENSG00000184160
# 2                  CHEMBL134            CLONIDINE  ENSG00000274286
# 3                  CHEMBL134            CLONIDINE  ENSG00000150594
# 4                  CHEMBL134            CLONIDINE  ENSG00000184160
# 5                  CHEMBL134            CLONIDINE  ENSG00000274286
# 6                  CHEMBL134            CLONIDINE  ENSG00000150594
# 7                  CHEMBL134            CLONIDINE  ENSG00000184160
# 8                  CHEMBL134            CLONIDINE  ENSG00000274286
# 9                  CHEMBL134            CLONIDINE  ENSG00000150594
# 10                 CHEMBL134            CLONIDINE  ENSG00000184160
# 11                 CHEMBL134            CLONIDINE  ENSG00000274286
# 12                 CHEMBL134            CLONIDINE  ENSG00000150594
# 13                 CHEMBL134            CLONIDINE  ENSG00000184160
# 14                 CHEMBL134            CLONIDINE  ENSG00000274286
# 15                 CHEMBL778      DEXMEDETOMIDINE  ENSG00000150594
# 16                 CHEMBL778      DEXMEDETOMIDINE  ENSG00000184160
# 17                 CHEMBL778      DEXMEDETOMIDINE  ENSG00000274286
# 18                 CHEMBL778      DEXMEDETOMIDINE  ENSG00000150594
# 19                 CHEMBL778      DEXMEDETOMIDINE  ENSG00000184160
# 20                 CHEMBL778      DEXMEDETOMIDINE  ENSG00000274286
# 21                 CHEMBL778      DEXMEDETOMIDINE  ENSG00000150594
# 22                 CHEMBL778      DEXMEDETOMIDINE  ENSG00000184160
# 23                 CHEMBL778      DEXMEDETOMIDINE  ENSG00000274286
# 24                 CHEMBL778      DEXMEDETOMIDINE  ENSG00000150594
# 25                 CHEMBL778      DEXMEDETOMIDINE  ENSG00000184160
# 26                 CHEMBL778      DEXMEDETOMIDINE  ENSG00000274286
# 27                 CHEMBL778      DEXMEDETOMIDINE  ENSG00000150594
# 28                 CHEMBL778      DEXMEDETOMIDINE  ENSG00000184160
# 29                 CHEMBL778      DEXMEDETOMIDINE  ENSG00000274286
#
#                                      MESH Heading  \
# 0   Attention Deficit Disorder with Hyperactivity
# 1   Attention Deficit Disorder with Hyperactivity
# 2   Attention Deficit Disorder with Hyperactivity
# 3          Child Development Disorders, Pervasive
# 4          Child Development Disorders, Pervasive
# 5          Child Development Disorders, Pervasive
# 6                        Opioid-Related Disorders
# 7                        Opioid-Related Disorders
# 8                        Opioid-Related Disorders
# 9                Stress Disorders, Post-Traumatic
# 10               Stress Disorders, Post-Traumatic
# 11               Stress Disorders, Post-Traumatic
# 12                                        Anxiety
# 13                                        Anxiety
# 14                                        Anxiety
# 15                                  Schizophrenia
# 16                                  Schizophrenia
# 17                                  Schizophrenia
# 18         Child Development Disorders, Pervasive
# 19         Child Development Disorders, Pervasive
# 20         Child Development Disorders, Pervasive
# 21                       Opioid-Related Disorders
# 22                       Opioid-Related Disorders
# 23                       Opioid-Related Disorders
# 24                              Alzheimer Disease
# 25                              Alzheimer Disease
# 26                              Alzheimer Disease
# 27                                        Anxiety
# 28                                        Anxiety
# 29                                        Anxiety
#
#                                    EFO Terms        EFO IDs  \
# 0   attention deficit hyperactivity disorder    EFO:0003888
# 1   attention deficit hyperactivity disorder    EFO:0003888
# 2   attention deficit hyperactivity disorder    EFO:0003888
# 3                   autism spectrum disorder    EFO:0003756
# 4                   autism spectrum disorder    EFO:0003756
# 5                   autism spectrum disorder    EFO:0003756
# 6                          opioid dependence    EFO:0005611
# 7                          opioid dependence    EFO:0005611
# 8                          opioid dependence    EFO:0005611
# 9             post-traumatic stress disorder    EFO:0001358
# 10            post-traumatic stress disorder    EFO:0001358
# 11            post-traumatic stress disorder    EFO:0001358
# 12                                   anxiety    EFO:0005230
# 13                                   anxiety    EFO:0005230
# 14                                   anxiety    EFO:0005230
# 15                             schizophrenia  MONDO:0005090
# 16                             schizophrenia  MONDO:0005090
# 17                             schizophrenia  MONDO:0005090
# 18                  autism spectrum disorder    EFO:0003756
# 19                  autism spectrum disorder    EFO:0003756
# 20                  autism spectrum disorder    EFO:0003756
# 21                         opioid dependence    EFO:0005611
# 22                         opioid dependence    EFO:0005611
# 23                         opioid dependence    EFO:0005611
# 24                         Alzheimer disease  MONDO:0004975
# 25                         Alzheimer disease  MONDO:0004975
# 26                         Alzheimer disease  MONDO:0004975
# 27                                   anxiety    EFO:0005230
# 28                                   anxiety    EFO:0005230
# 29                                   anxiety    EFO:0005230
#
#                                      Disease
# 0   Attention Deficit Hyperactivity Disorder
# 1   Attention Deficit Hyperactivity Disorder
# 2   Attention Deficit Hyperactivity Disorder
# 3                   Autism Spectrum Disorder
# 4                   Autism Spectrum Disorder
# 5                   Autism Spectrum Disorder
# 6                    Substance Use Disorders
# 7                    Substance Use Disorders
# 8                    Substance Use Disorders
# 9             Post Traumatic Stress Disorder
# 10            Post Traumatic Stress Disorder
# 11            Post Traumatic Stress Disorder
# 12                          Anxiety Disorder
# 13                          Anxiety Disorder
# 14                          Anxiety Disorder
# 15                             Schizophrenia
# 16                             Schizophrenia
# 17                             Schizophrenia
# 18                  Autism Spectrum Disorder
# 19                  Autism Spectrum Disorder
# 20                  Autism Spectrum Disorder
# 21                   Substance Use Disorders
# 22                   Substance Use Disorders
# 23                   Substance Use Disorders
# 24                       Alzheimer’s Disease
# 25                       Alzheimer’s Disease
# 26                       Alzheimer’s Disease
# 27                          Anxiety Disorder
# 28                          Anxiety Disorder
# 29                          Anxiety Disorder

# %%
merged_df.to_csv('../data/indication_gene_link/chembl_chembl_2.csv', index=False)

# %%
indication_names_by_disease = merged_df.groupby('Disease')['MESH Heading'].apply(lambda x: '; '.join(x.unique())).reset_index()
indication_names_df = pd.DataFrame(indication_names_by_disease)
indication_names_df.columns = ['Disease', 'MESH Heading']
indication_names_df.head(7)
indication_names_df.to_csv('../data/indication_gene_link/dictionary_chembl.csv', index=False)
